# %% [markdown]
# ## Import libraries from python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import sklearn
#from sklearn.model_selection import train_test_split
#from sklearn.datasets import make_classification, make_blobs
#from matplotlib.colors import ListedColormap
# %matplotlib notebook

# %% [markdown]
# # Import .csv file and store it as a dataframe

# %%
df = pd.read_csv('Ionosphere.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10      V11      V12      V13      V14      V15      V16      V17  \
# 0  0.03760  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223  0.84356
# 1 -0.04549  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515  0.05499
# 2  0.01198  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299  0.83775
# 3  0.00000  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516  0.54094
# 4 -0.16399  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457  0.52940
#
#        V18      V19      V20      V21      V22      V23      V24      V25  \
# ...

# %% [markdown]
# ## Check the shape of dataframe and null values in the dataframe

# %%
df.shape
# Out:
# (351, 35)

# %% [markdown]
# ## There is no null values in the dataset and all the datatypes in each columns are of same type.

# %%
df.isna().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V12      0
# V13      0
# V14      0
# V15      0
# V16      0
# V17      0
# V18      0
# V19      0
# V20      0
# V21      0
# V22      0
# V23      0
# V24      0
# V25      0
# V26      0
# V27      0
# V28      0
# V29      0
# V30      0
# V31      0
# V32      0
# V33      0
# V34      0
# Class    0
# dtype: int64

# %%
df.dtypes
# Out:
# V1         int64
# V2         int64
# V3       float64
# V4       float64
# V5       float64
# V6       float64
# V7       float64
# V8       float64
# V9       float64
# V10      float64
# V11      float64
# V12      float64
# V13      float64
# V14      float64
# V15      float64
# V16      float64
# V17      float64
# V18      float64
# V19      float64
# V20      float64
# V21      float64
# V22      float64
# V23      float64
# V24      float64
# V25      float64
# V26      float64
# V27      float64
# V28      float64
# V29      float64
# V30      float64
# V31      float64
# V32      float64
# V33      float64
# V34      float64
# Class      int64
# dtype: object

# %% [markdown]
# ## After visualizing the dataframe separate the features and target column

# %%
X=df.iloc[:,0:33]
Y=df.iloc[:,34]

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Class, dtype: int64

# %% [markdown]
# ## We will try to find out that whether all columns are on same scale by using visualization or .describe() method

# %%
df2 = df.copy()
df2.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10      V11      V12      V13      V14      V15      V16      V17  \
# 0  0.03760  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223  0.84356
# 1 -0.04549  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515  0.05499
# 2  0.01198  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299  0.83775
# 3  0.00000  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516  0.54094
# 4 -0.16399  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457  0.52940
#
#        V18      V19      V20      V21      V22      V23      V24      V25  \
# ...

# %%
plt.figure()
import matplotlib.dates as mdates
plt.scatter(df2.iloc[:,6:7],df2['Class'],c='red',label='6')
plt.scatter(df2.iloc[:,14:15],df2['Class'],c='green',label='14')
plt.scatter(df2.iloc[:,8:9],df2['Class'],c='b',label='8')
plt.scatter(df2.iloc[:,4:5],df2['Class'],c='c',label='4')
plt.scatter(df2.iloc[:,5:6],df2['Class'],c='m',label='5')
plt.scatter(df2.iloc[:,7:8],df2['Class'],c='y',label='7')
plt.scatter(df2.iloc[:,9:10],df2['Class'],c='k',label='9')
plt.scatter(df2.iloc[:,10:11],df2['Class'],c='black',label='10')
plt.scatter(df2.iloc[:,12:13],df2['Class'],c='red',label='12')
plt.scatter(df2.iloc[:,16:17],df2['Class'],c='lavender',label='16')
plt.scatter(df2.iloc[:,18:19],df2['Class'],c='salmon',label='18')
plt.scatter(df2.iloc[:,19:20],df2['Class'],c='coral',label='19')
plt.xlim(-1.2,1.2)
plt.xticks(np.arange(-1.2, 1.2, 0.1))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7514373556655">

# %%
df.describe()
# Out:
#                V1     V2          V3          V4          V5          V6  \
# count  351.000000  351.0  351.000000  351.000000  351.000000  351.000000
# mean     0.891738    0.0    0.641342    0.044372    0.601068    0.115889
# std      0.311155    0.0    0.497708    0.441435    0.519862    0.460810
# min      0.000000    0.0   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.0    0.472135   -0.064735    0.412660   -0.024795
# 50%      1.000000    0.0    0.871110    0.016310    0.809200    0.022800
# 75%      1.000000    0.0    1.000000    0.194185    1.000000    0.334655
# max      1.000000    0.0    1.000000    1.000000    1.000000    1.000000
#
#                V7          V8          V9         V10         V11         V12  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean     0.550095    0.119360    0.511848    0.181345    0.476183    0.155040
# ...

# %% [markdown]
# ## Since all the columns are on same numeric scale, so we need not to worry about it.

# %% [markdown]
# # Next Step
# ## We will try to plot a half matrix for better visualization

# %%
np.random.seed(0)
plt.figure()
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    p2 = sns.heatmap(corr_matrix, mask=mask, square=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7514373556655">

# %% [markdown]
# ## Most of columns are not correlated. So we can't reduce their numbers.

# %% [markdown]
# # Machine Learing Algorithms
# # Classification or regression

# %% [markdown]
# ## Since out target columns contains only two unique values. So It has to be a classfication problem.

# %%
Y.unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state = 42)

# %%
clf = DecisionTreeClassifier(random_state = 42).fit(X_train, y_train)

# %%
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.86

# %% [markdown]
# ## For better result, we try to use alter the tree depth

# %%
clf2 = DecisionTreeClassifier(max_depth = 3).fit(X_train, y_train)

# %%
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf2.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf2.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.92
# Accuracy of Decision Tree classifier on test set: 0.86

# %% [markdown]
# #  RandomForest Classfier

# %%
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state = 42)

clf = RandomForestClassifier(max_features = 12, random_state = 42)
clf.fit(X_train, y_train)

print('Accuracy of RF classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of RF classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of RF classifier on training set: 1.00
# Accuracy of RF classifier on test set: 0.93

# %% [markdown]
# # We will again try to verify results by confusion matrix

# %%
from sklearn.metrics import confusion_matrix

clf = RandomForestClassifier(max_features = 12, random_state = 42)
clf.fit(X_train, y_train)
predicted=clf.predict(X_test)
confusion = confusion_matrix(y_test,predicted)

print ('Most frequent class \n', confusion)
# Out:
# Most frequent class
#  [[28  4]
#  [ 2 54]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predicted)))
print('Precision: {:.2f}'.format(precision_score(y_test, predicted)))
print('Recall: {:.2f}'.format(recall_score(y_test, predicted)))
print('F1: {:.2f}'.format(f1_score(y_test, predicted)))
# Out:
# Accuracy: 0.93
# Precision: 0.93
# Recall: 0.96
# F1: 0.95

# %% [markdown]
# # Logistic Regression Classfier

# %%
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state = 42)

clf = LogisticRegression(random_state= 42).fit(X_train, y_train)

print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.91
# Accuracy of Logistic regression classifier on test set: 0.86
